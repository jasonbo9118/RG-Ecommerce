# %%
# %sql

USE CATALOG ecommerce;

CREATE SCHEMA IF NOT EXISTS raw;

CREATE EXTERNAL VOLUME IF NOT EXISTS ecommerce.raw.landing
  LOCATION 'abfss://ecomm-raw-data@stgecommercedevwestus001.dfs.core.windows.net/'
  COMMENT 'Raw ADLS Gen2 landing for ecommerce';
